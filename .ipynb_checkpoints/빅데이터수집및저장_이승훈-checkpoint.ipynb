# %%
# 1번, 2번, 4번

import requests
import bs4

url = "https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cnt&date=20210520"
response = requests.get(url)

# XML일 경울 lxml-xml, HTML일 경우 html.parser
soup = bs4.BeautifulSoup(response.text, 'html.parser')

moviename = []
movielink = []
movieactor = []
moviearr = []

for tmp in soup.select("#old_content > table > tbody > tr > td > div > a", limit=5):
#     print(tmp.text, "https://movie.naver.com" + tmp.attrs['href'])
    movielink.append("https://movie.naver.com" + tmp.attrs['href'])
    
for i in movielink:
    response = requests.get(i)
    
    soup = bs4.BeautifulSoup(response.text, 'html.parser')
    soup
    
    title = ["a", "b", "c", "d", "e", "f", "g", "h"]
    moviedic = {}
    moviedic = dict.fromkeys(title)
    
    # 영화제목
    for tmp9 in soup.select("#content > div.article > div.mv_info_area > div.mv_info > h3 > a:nth-child(1)"):
        moviedic[title[0]] = tmp9.text
    
    # 관람등급
    for idx, tmp1 in enumerate(soup.select("#content > div.article > div.mv_info_area > div.mv_info > dl > dd:nth-child(8) > p > a")):
        if(idx != 0):
            break
        moviedic[title[1]]=tmp1.text
        
    # 관람평점
    for tmp2 in soup.select("#actualPointPersentBasic > div > span > span"):
        moviedic[title[2]]=float(tmp2.text.replace("관람객 평점 ", "").replace("점", ""))
                                  
#     # 장르
#     moviegenretmp = []
#     for tmp3 in soup.select("#content > div.article > div.mv_info_area > div.mv_info > dl > dd:nth-child(2) > p > span:nth-child(1) > a"):
#         moviegenretmp.append((tmp3.text))
#     moviegenre.append(moviegenretmp)
    
    # 장르
    for tmp3 in soup.select("#content > div.article > div.mv_info_area > div.mv_info > dl > dd:nth-child(2) > p > span:nth-child(1)"):
        tempstr = ""
        for tmp8 in tmp3.find_all("a"):
            tempstr += tmp8.text
            tempstr +=  ", "
    moviedic[title[3]] = tempstr[:-2]
    
    # 상영시간
    for tmp4 in soup.select("#content > div.article > div.mv_info_area > div.mv_info > dl > dd:nth-child(2) > p > span:nth-child(3)"):
        moviedic[title[4]] = tmp4.text
        
    # 개봉일
    stringtemp=""
    for tmp5 in soup.select("#content > div.article > div.mv_info_area > div.mv_info > dl > dd:nth-child(2) > p > span:nth-child(4) > a"):
        stringtemp += tmp5.text
    moviedic[title[5]] = stringtemp
    
    # 감독
    for tmp6 in soup.select("#content > div.article > div.mv_info_area > div.mv_info > dl > dd:nth-child(4) > p > a"):
        moviedic[title[6]] = tmp6.text
        
    # 출연배우
    for tmp7 in soup.select("#content > div.article > div.mv_info_area > div.mv_info > dl > dd:nth-child(6) > p"):
        moviedic[title[7]] = tmp7.text
    
        moviearr.append(moviedic)
print(moviearr)
# Out:
# [{'a': '분노의 질주: 더 얼티메이트', 'b': '12세 관람가', 'c': 9.04, 'd': '액션', 'e': '142분 ', 'f': ' 2021.05.19', 'g': '저스틴 린', 'h': '빈 디젤(도미닉 토레토), 존 시나(제이콥 토레토), 성 강(한)'}, {'a': '스파이럴', 'b': '청소년 관람불가', 'c': 7.78, 'd': '스릴러', 'e': '93분 ', 'f': ' 2021.05.12', 'g': '대런 린 보우즈만', 'h': '크리스 록, 사무엘 L. 잭슨, 마리솔 니콜스'}, {'a': '더 스파이', 'b': '15세 관람가', 'c': 8.77, 'd': '스릴러', 'e': '112분 ', 'f': ' 2021.04.28', 'g': '도미닉 쿡', 'h': '베네딕트 컴버배치(그레빌 윈)'}, {'a': '크루즈 패밀리: 뉴 에이지', 'b': '전체 관람가', 'c': 9.35, 'd': '애니메이션, 모험, 코미디', 'e': '95분 ', 'f': ' 2021.05.05', 'g': '조엘 크로포드', 'h': '엠마 스톤(이프 목소리), 라이언 레이놀즈(가이 목소리), 켈리 마리 트란(던 목소리)'}, {'a': '극장판 귀멸의 칼날: 무한열차편', 'b': '15세 관람가', 'c': 9.62, 'd': '애니메이션', 'e': '117분 ', 'f': ' 2021.01.27', 'g': '소토자키 하루오', 'h': '하나에 나츠키(카마도 탄지로 목소리), 키토 아카리(카마도 네즈코 목소리)'}]

# %%
# 3번

import requests
from selenium import webdriver  # pip install selenium
import bs4 # pip install bs4
import time
import urllib.request as REQ  #서버 요청
from selenium.webdriver.common.keys import Keys

url = "https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cnt&date=20210520"
response = requests.get(url)

# XML일 경울 lxml-xml, HTML일 경우 html.parser
soup = bs4.BeautifulSoup(response.text, 'html.parser')

moviename = []
movielink = []
movieactor = []
moviearr = []
for tmp in soup.select("#old_content > table > tbody > tr > td > div > a", limit=5):
#     print(tmp.text, "https://movie.naver.com" + tmp.attrs['href'])
    movielink.append("https://movie.naver.com" + tmp.attrs['href'])
    
for i in movielink:
    response = requests.get(i)

    soup = bs4.BeautifulSoup(response.text, 'html.parser')
    soup
    
    title = ["title", "link"]
    moviedic = {}
    moviedic = dict.fromkeys(title)
    
    # 영화제목
    for tmp9 in soup.select("#content > div.article > div.mv_info_area > div.mv_info > h3 > a:nth-child(1)"):
        moviedic[title[0]] = tmp9.text
        moviedic[title[1]] = i
    moviearr.append(moviedic)

# 옵션설정
options = webdriver.ChromeOptions()
options.add_argument("disable-gpu")   
options.add_argument("lang=ko_KR")  
options.add_argument("headless")  # 크롬창이 표시되지 않음
options.add_argument('user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36')  # user-agent 

# 드라이브 로딩
driver = webdriver.Chrome(executable_path="driver/chromedriver.exe", options=options)
for idx, tmp in enumerate(moviearr):
    print(idx, moviearr[idx]["link"])
    driver.get(moviearr[idx]["link"])
    time.sleep(1)
    try:
        img = driver.find_element_by_xpath(f'//*[@id="content"]/div[1]/div[1]/div[1]/a/img')
        REQ.urlretrieve( img.get_attribute("src"), f'download/{moviearr[idx]["title"].replace(":","")}.jpg' )
    except Exception as e:
        print(e)
driver.close()
# Out:
# 0 https://movie.naver.com/movie/bi/mi/basic.nhn?code=189150
# 1 https://movie.naver.com/movie/bi/mi/basic.nhn?code=191570
# 2 https://movie.naver.com/movie/bi/mi/basic.nhn?code=191914
# 3 https://movie.naver.com/movie/bi/mi/basic.nhn?code=107992
# 4 https://movie.naver.com/movie/bi/mi/basic.nhn?code=196051

# %%
import pymongo

try:
    username = "id120"
    password = "pw120"
    host = "1.234.5.158"
    port = 37017
    dbname = "id120"
    
    # mongodb 접속
    conn= pymongo.MongoClient(f'mongodb://{username}:{password}@{host}:{port}/{dbname}')
    db = conn.get_database(dbname) #db선택
    collection = db.get_collection("exam_movie") #collection == table과 비슷함
    
    collection.insert_many(moviearr)
    
except Exception as e:
    print(e)
finally:
    conn.close()

# %%
# 몽고db확인
import pymongo

try:
    username = "id120"
    password = "pw120"
    host = "1.234.5.158"
    port = 37017
    dbname = "id120"
    
    # mongodb 접속
    conn= pymongo.MongoClient(f'mongodb://{username}:{password}@{host}:{port}/{dbname}')
    db = conn.get_database(dbname) #db선택
    collection = db.get_collection("exam_movie") #collection == table과 비슷함
    
    data6 = collection.find({}, {'_id':0})

    for tmp in data6:
        print(tmp)
except Exception as e:
    print(e)
finally:
    conn.close()
# Out:
# {'a': '분노의 질주: 더 얼티메이트', 'b': '12세 관람가', 'c': 9.08, 'd': '액션', 'e': '142분 ', 'f': ' 2021.05.19', 'g': '저스틴 린', 'h': '빈 디젤(도미닉 토레토), 존 시나(제이콥 토레토), 성 강(한)'}
# {'a': '스파이럴', 'b': '청소년 관람불가', 'c': 7.86, 'd': '스릴러', 'e': '93분 ', 'f': ' 2021.05.12', 'g': '대런 린 보우즈만', 'h': '크리스 록, 사무엘 L. 잭슨, 마리솔 니콜스'}
# {'a': '더 스파이', 'b': '15세 관람가', 'c': 8.78, 'd': '스릴러', 'e': '112분 ', 'f': ' 2021.04.28', 'g': '도미닉 쿡', 'h': '베네딕트 컴버배치(그레빌 윈)'}
# {'a': '크루즈 패밀리: 뉴 에이지', 'b': '전체 관람가', 'c': 9.34, 'd': '애니메이션, 모험, 코미디', 'e': '95분 ', 'f': ' 2021.05.05', 'g': '조엘 크로포드', 'h': '엠마 스톤(이프 목소리), 라이언 레이놀즈(가이 목소리), 켈리 마리 트란(던 목소리)'}
# {'a': '극장판 귀멸의 칼날: 무한열차편', 'b': '15세 관람가', 'c': 9.62, 'd': '애니메이션', 'e': '117분 ', 'f': ' 2021.01.27', 'g': '소토자키 하루오', 'h': '하나에 나츠키(카마도 탄지로 목소리), 키토 아카리(카마도 네즈코 목소리)'}

# %%
# 5번
import hdfs
import json

client_hdfs = hdfs.InsecureClient('http://1.234.5.158:9870', user='hdfs')

client_hdfs.delete('/id120/exam_movie.json')

with client_hdfs.write('/id120/exam_movie.json', encoding = "utf-8" ) as writer:
    json.dump(moviearr, writer)

# %%
# HADDOP 확인
from hdfs import InsecureClient
import pandas as pd

client_hdfs = InsecureClient('http://1.234.5.158:9870', user='hdfs')

# 파일 목록 확인
print(client_hdfs.list('/id120'))

# 파일 내용 읽기
with client_hdfs.read('/id120/exam_movie.json', encoding="utf-8") as reader:
    df = pd.read_json(reader)
#     for tmp in reader:
#         print(tmp)
df
# Out:
# ['datalab_naver_20210525.json', 'ex_20210525.json', 'exam_movie.json', 'shopping_kakao_20210525.json']
#                    a         b     c               d      e            f  \
# 0    분노의 질주: 더 얼티메이트   12세 관람가  9.04              액션  142분    2021.05.19
# 1               스파이럴  청소년 관람불가  7.78             스릴러   93분    2021.05.12
# 2              더 스파이   15세 관람가  8.77             스릴러  112분    2021.04.28
# 3     크루즈 패밀리: 뉴 에이지    전체 관람가  9.35  애니메이션, 모험, 코미디   95분    2021.05.05
# 4  극장판 귀멸의 칼날: 무한열차편   15세 관람가  9.62           애니메이션  117분    2021.01.27
#
#            g                                                 h
# 0      저스틴 린              빈 디젤(도미닉 토레토), 존 시나(제이콥 토레토), 성 강(한)
# 1  대런 린 보우즈만                         크리스 록, 사무엘 L. 잭슨, 마리솔 니콜스
# 2      도미닉 쿡                                  베네딕트 컴버배치(그레빌 윈)
# 3    조엘 크로포드  엠마 스톤(이프 목소리), 라이언 레이놀즈(가이 목소리), 켈리 마리 트란(던 목소리)
# 4   소토자키 하루오         하나에 나츠키(카마도 탄지로 목소리), 키토 아카리(카마도 네즈코 목소리)
